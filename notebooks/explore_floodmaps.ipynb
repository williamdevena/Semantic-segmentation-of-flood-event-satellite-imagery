# %%
import geopandas as gpd
import glob 


files=glob.glob("../WORLDFLOODS/val/floodmaps/*.dbf")
#files=glob.glob("../WORLDFLOODS/val/floodmaps/*.shp")
#files=glob.glob("../WORLDFLOODS/val/floodmaps/*.shx")


for shapefile in files:
    shape=gpd.read_file(shapefile)
    shape.plot()

# %%
shape=gpd.read_file("../WORLDFLOODS/val/floodmaps/EMSR271_02FARKADONA_DEL_v1_observed_event_a.dbf")
shape.plot()
# Out:
# <AxesSubplot:>

# %%
shape=gpd.read_file("../WORLDFLOODS/val/floodmaps/EMSR271_02FARKADONA_DEL_v1_observed_event_a.shp")
shape.plot()
# Out:
# <AxesSubplot:>

# %%
shape=gpd.read_file("../WORLDFLOODS/val/floodmaps/EMSR271_02FARKADONA_DEL_v1_observed_event_a.shx")
shape.plot()
# Out:
# <AxesSubplot:>
